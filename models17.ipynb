# %%
import pandas as pd
vms = pd.DataFrame({'vms': ['hotspot','openj9', 'graal']})
patterns = pd.DataFrame({'patterns': ['interpreter', 'switch', 'visitor', 'monolythic revisitor', 'modular revisitor']})
programs = pd.DataFrame({'programs': ['UC1', 'UC2', 'UC3']})

def product(df1, df2, pivot='key'):
    df1[pivot]=0
    df2[pivot]=0
    return df1.merge(df2, on=pivot, how='outer').drop(columns=[pivot])
    
    
product(product(vms, patterns), programs)
# Out:
#         vms              patterns programs
# 0   hotspot           interpreter      UC1
# 1   hotspot           interpreter      UC2
# 2   hotspot           interpreter      UC3
# 3   hotspot                switch      UC1
# 4   hotspot                switch      UC2
# 5   hotspot                switch      UC3
# 6   hotspot               visitor      UC1
# 7   hotspot               visitor      UC2
# 8   hotspot               visitor      UC3
# 9   hotspot  monolythic revisitor      UC1
# 10  hotspot  monolythic revisitor      UC2
# 11  hotspot  monolythic revisitor      UC3
# 12  hotspot     modular revisitor      UC1
# 13  hotspot     modular revisitor      UC2
# 14  hotspot     modular revisitor      UC3
# 15   openj9           interpreter      UC1
# 16   openj9           interpreter      UC2
# 17   openj9           interpreter      UC3
# 18   openj9                switch      UC1
# 19   openj9                switch      UC2
# 20   openj9                switch      UC3
# 21   openj9               visitor      UC1
# 22   openj9               visitor      UC2
# 23   openj9               visitor      UC3
# 24   openj9  monolythic revisitor      UC1
# 25   openj9  monolythic revisitor      UC2
# 26   openj9  monolythic revisitor      UC3
# 27   openj9     modular revisitor      UC1
# 28   openj9     modular revisitor      UC2
# 29   openj9     modular revisitor      UC3
# 30    graal           interpreter      UC1
# 31    graal           interpreter      UC2
# 32    graal           interpreter      UC3
# 33    graal                switch      UC1
# 34    graal                switch      UC2
# 35    graal                switch      UC3
# 36    graal               visitor      UC1
# 37    graal               visitor      UC2
# 38    graal               visitor      UC3
# 39    graal  monolythic revisitor      UC1
# 40    graal  monolythic revisitor      UC2
# 41    graal  monolythic revisitor      UC3
# 42    graal     modular revisitor      UC1
# 43    graal     modular revisitor      UC2
# 44    graal     modular revisitor      UC3
